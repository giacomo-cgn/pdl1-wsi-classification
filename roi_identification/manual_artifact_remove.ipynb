# %%
import numpy as np
import matplotlib.pyplot as plt
import openslide
import cv2 as cv
from define_dataset import define_dataset
from define_ext_dataset import define_ext_dataset
from PIL import Image

# %%
dataset = define_dataset()
tr_set = dataset.tr_set
test_set = dataset.test_set
results_dict = dataset.results_dict
num_positives = dataset.num_positives
num_negatives = dataset.num_negatives
print(results_dict)
# Out:
# {'19-COMP-004': 1, '19-COMP-011': 1, '19-COMP-012': 1, '19-COMP-014': 1, '19-COMP-016': 1, '19-COMP-019': 1, '19-COMP-026': 1, '19-COMP-029': 1, '19-COMP-030': 1, '19-COMP-032': 1, '19-COMP-034': 1, '19-COMP-037': 1, '20-COMP-050': 1, '20-COMP-052': 1, '20-COMP-054': 1, '20-COMP-071': 1, '20-COMP-088': 1, '20-COMP-102': 1, '20-COMP-103': 1, '20-COMP-113': 1, '19-COMP-017': 0, '19-COMP-020': 0, '19-COMP-021': 0, '19-COMP-039': 0, '19-COMP-044': 0, '19-COMP-047': 0, '20-COMP-055': 0, '20-COMP-056': 0, '20-COMP-059': 0, '20-COMP-063': 0, '20-COMP-065': 0, '20-COMP-066': 0, '20-COMP-068': 0, '20-COMP-070': 0, '20-COMP-073': 0, '20-COMP-075': 0, '20-COMP-076': 0, '20-COMP-077': 0, '20-COMP-078': 0}

# %%
slide_name = '19-COMP-044'
ROI_threshold = 0.85

wsi_path = '../WSI/thesis_WSI/'+slide_name+'/'+slide_name+'.tiff'
ROI_mask_path = '../WSI/thesis_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_enhanced.npy'
ROI_mask_arr = np.load(ROI_mask_path)

thumbnail = openslide.OpenSlide(wsi_path).get_thumbnail((ROI_mask_arr.shape[1], ROI_mask_arr.shape[0]))



plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(ROI_mask_arr, cmap='gray', alpha=0.2) # interpolation='none'
plt.show()

#np.set_printoptions(threshold=np.inf)
#print(ROI_mask_arr)

over_mask = np.ones(ROI_mask_arr.shape)
over_mask[48:51, 93:96] = 0
over_mask[69:73, 95:104] = 0
over_mask[92:106, 145:155] = 0
over_mask[108:127, 158:210] = 0
over_mask[125:155, 170:210] = 0
over_mask[178:188, 196:204] = 0
over_mask[199:204, 128:137] = 0


plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(over_mask, cmap='inferno', alpha=0.3) # interpolation='none'
plt.show()

end_mask = np.logical_and(ROI_mask_arr, over_mask)
plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(end_mask, cmap='gray', alpha=0.2) # interpolation='none'
plt.show()

np.save('../WSI/thesis_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_manual.npy', end_mask)

# %%
slide_name = '20-COMP-063'
ROI_threshold = 0.85

wsi_path = '../WSI/thesis_WSI/'+slide_name+'/'+slide_name+'.tiff'
ROI_mask_path = '../WSI/thesis_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_enhanced.npy'
ROI_mask_arr = np.load(ROI_mask_path)

#thumbnail = openslide.OpenSlide(wsi_path).get_thumbnail((ROI_mask_arr.shape[1], ROI_mask_arr.shape[0]))



#plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(ROI_mask_arr, cmap='gray', alpha=0.2) # interpolation='none'
plt.show()

#np.set_printoptions(threshold=np.inf)
#print(ROI_mask_arr)

over_mask = np.ones(ROI_mask_arr.shape)
over_mask[50:175, 110:130] = 0
over_mask[215:225, 153:210] = 0
over_mask[225:248, 175:182] = 0
over_mask[253:257, 179:182] = 0
over_mask[254:260, 195:201] = 0
over_mask[275:281, 175:185] = 0
over_mask[284:290, 195:205] = 0
over_mask[152:183, 147:170] = 0
over_mask[284:290, 260:270] = 0
over_mask[180:186, 220:226] = 0
over_mask[10:94, 223:310] = 0
over_mask[10:50, 180:223] = 0


over_mask[217:221, 172:181] = 1


plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(over_mask, cmap='inferno', alpha=0.3) # interpolation='none'
plt.show()

end_mask = np.logical_and(ROI_mask_arr, over_mask)
plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(end_mask, cmap='gray', alpha=0.2) # interpolation='none'
plt.show()

np.save('../WSI/thesis_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_manual.npy', end_mask)

# %%
slide_name = '20-COMP-065'
ROI_threshold = 0.85

wsi_path = '../WSI/thesis_WSI/'+slide_name+'/'+slide_name+'.tiff'
ROI_mask_path = '../WSI/thesis_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_enhanced.npy'
ROI_mask_arr = np.load(ROI_mask_path)

#thumbnail = openslide.OpenSlide(wsi_path).get_thumbnail((ROI_mask_arr.shape[1], ROI_mask_arr.shape[0]))



#plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(ROI_mask_arr, cmap='gray', alpha=0.2) # interpolation='none'
plt.show()

#np.set_printoptions(threshold=np.inf)
#print(ROI_mask_arr)

over_mask = np.ones(ROI_mask_arr.shape)
over_mask[112:138, 118:132] = 0
over_mask[138:148, 112:122] = 0
over_mask[123:143, 152:172] = 0
over_mask[143:156, 159:174] = 0
over_mask[148:152, 174:205] = 0
over_mask[94:98, 143:157] = 0
#over_mask[199:204, 128:137] = 0


plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(over_mask, cmap='inferno', alpha=0.3) # interpolation='none'
plt.show()

end_mask = np.logical_and(ROI_mask_arr, over_mask)
plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(end_mask, cmap='gray', alpha=0.2) # interpolation='none'
plt.show()

np.save('../WSI/thesis_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_manual.npy', end_mask)

# %%
slide_name = '20-COMP-068'
ROI_threshold = 0.85

wsi_path = '../WSI/thesis_WSI/'+slide_name+'/'+slide_name+'.tiff'
ROI_mask_path = '../WSI/thesis_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_enhanced.npy'
ROI_mask_arr = np.load(ROI_mask_path)

#thumbnail = openslide.OpenSlide(wsi_path).get_thumbnail((ROI_mask_arr.shape[1], ROI_mask_arr.shape[0]))



#plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(ROI_mask_arr, cmap='gray', alpha=0.2) # interpolation='none'
plt.show()

#np.set_printoptions(threshold=np.inf)
#print(ROI_mask_arr)

over_mask = np.ones(ROI_mask_arr.shape)
over_mask[15:80, 110:200] = 0
over_mask[290:330, 295:320] = 0
over_mask[353:358, 188:194] = 0
over_mask[290:322, 105:165] = 0
over_mask[70:120, 50:100] = 0
over_mask[103:123, 100:135] = 0
over_mask[385:410, 130:145] = 0


plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(over_mask, cmap='inferno', alpha=0.3) # interpolation='none'
plt.show()

end_mask = np.logical_and(ROI_mask_arr, over_mask)
plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(end_mask, cmap='gray', alpha=0.4) # interpolation='none'
plt.show()

np.save('../WSI/thesis_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_manual.npy', end_mask)

# %% [markdown]
# # Ext dataset

# %%
ext_dataset = define_ext_dataset()

ext_ts_set = ext_dataset.data
ext_results_dict = ext_dataset.results_dict
num_positive_ext = ext_dataset.num_positives
num_negatives_ext = ext_dataset.num_negatives
batches_ext = [ext_dataset.batch1, ext_dataset.batch2, ext_dataset.batch3]

# %%
slide_name = 'M-5428-20 SP142'
ROI_threshold = 0.85

wsi_path = '../WSI/ext_WSI/'+slide_name+'/'+slide_name+'.tiff'
ROI_mask_path = '../WSI/ext_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_enhanced.npy'
ROI_mask_arr = np.load(ROI_mask_path)

print('x:', ROI_mask_arr.shape[1], 'y:', ROI_mask_arr.shape[0])

thumbnail = Image.open('../WSI/ext_WSI/'+slide_name+'/thumbnail.jpg')



plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(ROI_mask_arr, cmap='gray', alpha=0.4) # interpolation='none'
plt.show()

#np.set_printoptions(threshold=np.inf)
#print(ROI_mask_arr)

over_mask = np.ones(ROI_mask_arr.shape)
over_mask[0:170, 0:383] = 0
over_mask[234:245, 58:65] = 0
over_mask[188:195, 120:127] = 0
over_mask[204:209, 117:122] = 0
over_mask[380:385, 308:312] = 0





plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(over_mask, cmap='inferno', alpha=0.3) # interpolation='none'
plt.show()

end_mask = np.logical_and(ROI_mask_arr, over_mask)
plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(end_mask, cmap='gray', alpha=0.4) # interpolation='none'
plt.show()

np.save('../WSI/ext_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_manual.npy', end_mask)
# Out:
# x: 383 y: 556

# %%
slide_name = 'M-5697-20 SP142'
ROI_threshold = 0.85

wsi_path = '../WSI/ext_WSI/'+slide_name+'/'+slide_name+'.tiff'
ROI_mask_path = '../WSI/ext_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_enhanced.npy'
ROI_mask_arr = np.load(ROI_mask_path)

print('x:', ROI_mask_arr.shape[1], 'y:', ROI_mask_arr.shape[0])

thumbnail = Image.open('../WSI/ext_WSI/'+slide_name+'/thumbnail.jpg')



plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(ROI_mask_arr, cmap='gray', alpha=0.4) # interpolation='none'
plt.show()

#np.set_printoptions(threshold=np.inf)
#print(ROI_mask_arr)

over_mask = np.ones(ROI_mask_arr.shape)
over_mask[0:90, 0:90] = 0
over_mask[270:294, 265:300] = 0
over_mask[575:640, 150:290] = 0
over_mask[325:333, 190:198] = 0

plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(over_mask, cmap='inferno', alpha=0.3) # interpolation='none'
plt.show()

end_mask = np.logical_and(ROI_mask_arr, over_mask)
plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(end_mask, cmap='gray', alpha=0.4) # interpolation='none'
plt.show()

np.save('../WSI/ext_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_manual.npy', end_mask)
# Out:
# x: 312 y: 640

# %%
slide_name = 'M-4092-20 SP142 (2)'
ROI_threshold = 0.85

wsi_path = '../WSI/ext_WSI/'+slide_name+'/'+slide_name+'.tiff'
ROI_mask_path = '../WSI/ext_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_enhanced.npy'
ROI_mask_arr = np.load(ROI_mask_path)

print('x:', ROI_mask_arr.shape[1], 'y:', ROI_mask_arr.shape[0])

thumbnail = Image.open('../WSI/ext_WSI/'+slide_name+'/thumbnail.jpg')

#np.set_printoptions(threshold=np.inf)
#print(ROI_mask_arr)
plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(ROI_mask_arr, cmap='gray', alpha=0.4) # interpolation='none'
plt.show()

over_mask = np.ones(ROI_mask_arr.shape)
over_mask[0:180, 120:160] = 0
over_mask[285:300, 50:70] = 0

plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(over_mask, cmap='inferno', alpha=0.3) # interpolation='none'
plt.show()

end_mask = np.logical_and(ROI_mask_arr, over_mask)
plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(end_mask, cmap='gray', alpha=0.4) # interpolation='none'
plt.show()

np.save('../WSI/ext_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_manual.npy', end_mask)
# Out:
# x: 154 y: 305

# %%
slide_name = 'M-3454-20-A1 SP142'
ROI_threshold = 0.85

wsi_path = '../WSI/ext_WSI/'+slide_name+'/'+slide_name+'.tiff'
ROI_mask_path = '../WSI/ext_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_enhanced.npy'
ROI_mask_arr = np.load(ROI_mask_path)

print('x:', ROI_mask_arr.shape[1], 'y:', ROI_mask_arr.shape[0])

thumbnail = Image.open('../WSI/ext_WSI/'+slide_name+'/thumbnail.jpg')


plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(ROI_mask_arr, cmap='gray', alpha=0.2) # interpolation='none'
plt.show()

#np.set_printoptions(threshold=np.inf)
#print(ROI_mask_arr)

over_mask = np.ones(ROI_mask_arr.shape)
over_mask[170:280, 0:40] = 0
over_mask[275:310, 100:138] = 0
over_mask[255:330, 312:321] = 0
over_mask[100:124, 320:333] = 0


plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(over_mask, cmap='inferno', alpha=0.3) # interpolation='none'
plt.show()

end_mask = np.logical_and(ROI_mask_arr, over_mask)
plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(end_mask, cmap='gray', alpha=0.4) # interpolation='none'
plt.show()

np.save('../WSI/ext_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_manual.npy', end_mask)
# Out:
# x: 340 y: 332

# %%
slide_name = 'M-1163-20 SP142'
ROI_threshold = 0.85

wsi_path = '../WSI/ext_WSI/'+slide_name+'/'+slide_name+'.tiff'
ROI_mask_path = '../WSI/ext_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_enhanced.npy'
ROI_mask_arr = np.load(ROI_mask_path)

print('x:', ROI_mask_arr.shape[1], 'y:', ROI_mask_arr.shape[0])

thumbnail = Image.open('../WSI/ext_WSI/'+slide_name+'/thumbnail.jpg')


plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(ROI_mask_arr, cmap='gray', alpha=0.0) # interpolation='none'
plt.show()

#np.set_printoptions(threshold=np.inf)
#print(ROI_mask_arr)

over_mask = np.ones(ROI_mask_arr.shape)
over_mask[50:117, 0:55] = 0
over_mask[0:32, 35:78] = 0
over_mask[0:63, 47:72] = 0
over_mask[93:136, 0:35] = 0
over_mask[136:185, 0:14] = 0



plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(over_mask, cmap='inferno', alpha=0.3) # interpolation='none'
plt.show()

end_mask = np.logical_and(ROI_mask_arr, over_mask)
plt.imshow(thumbnail) # I would add interpolation='none'
plt.imshow(end_mask, cmap='gray', alpha=0.2) # interpolation='none'
plt.show()

np.save('../WSI/ext_WSI/'+slide_name+'/roi_'+str(ROI_threshold)+'_manual.npy', end_mask)
# Out:
# x: 221 y: 244
